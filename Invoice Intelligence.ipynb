# %% [markdown]
# <a href="https://colab.research.google.com/github/Lohith-Muniganti/Data-Science-Projects/blob/main/Invoice%20Intelligence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
